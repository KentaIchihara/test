# %%
# !pip install jupyter
# Out:
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install psycopg2
# !pip install ipython-sql
# Out:
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
#   Running setup.py bdist_wheel for prettytable: started
#   Running setup.py bdist_wheel for prettytable: finished with status 'done'
#   Stored in directory: C:\Users\kenta_ichihara\AppData\Local\pip\Cache\wheels\80\34\1c\3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built prettytable
# ...
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# %load_ext sql
# %sql postgresql://snaga@localhost/testdb
# Out:
# (psycopg2.OperationalError) fe_sendauth: no password supplied
#  (Background on this error at: http://sqlalche.me/e/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# 必要なライブラリを読み込む
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 必要な関数を読み込む
from sklearn.model_selection import train_test_split # 訓練データと検証データに分ける関数
from sklearn.metrics import confusion_matrix, accuracy_score # 混同行列, 予測正解率を求める関数

# Jupyter 上で図を表示するためのコマンド
# %matplotlib inline

# seabornのデフォルトパラメータに設定するコマンド
sns.set()

import matplotlib as mpl
mpl.rcParams['font.family'] = 'IPAPGothic'
plt.rcParams['font.family']='HGMaruGothicMPRO'

# %%
import psycopg2

# %%
data = pd.read_csv('ro_data.csv')

# %%
data.dtypes
# Out:
# user_id          int64
# order_date      object
# order_amount     int64
# dtype: object

# %%
data['order_date'] = pd.to_datetime(data['order_date'])

# %%
data['order_date'] = data['order_date'].dt.strftime('%Y-%m-%d')

# %%
data['order_date'].max(), data['order_date'].min()
# Out:
# ('2017-11-20', '2016-07-09')

# %%
data['order_date'].describe()
# Out:
# count          10000
# unique           500
# top       2017-02-26
# freq              37
# Name: order_date, dtype: object

# %%
# SQLに接続
connection = psycopg2.connect("dbname=ojt_ro_data host=localhost user=postgres password=Password")
connection.get_backend_pid()
# Out:
# 8360

# %%
cur = connection.cursor()
print(cur)
# Out:
# <cursor object at 0x0000022109B27828; closed: 0>

# %%
d = '2015-12-20'
d1 = "select * from rfmrank2('" + d +"');"
cur.execute(d1)
results = cur.fetchall()
test0 = pd.DataFrame(results)
test0
# Out:
#        0           1  2
# 0    181  2015-12-20  D
# 1    962  2015-12-20  D
# 2    488  2015-12-20  D
# 3    131  2015-12-20  D
# 4    858  2015-12-20  D
# 5    954  2015-12-20  D
# 6    756  2015-12-20  D
# 7    423  2015-12-20  D
# 8    243  2015-12-20  D
# 9    135  2015-12-20  D
# 10    94  2015-12-20  D
# 11   294  2015-12-20  D
# 12   952  2015-12-20  D
# 13    25  2015-12-20  D
# 14   728  2015-12-20  D
# 15   937  2015-12-20  D
# 16   362  2015-12-20  D
# 17   204  2015-12-20  D
# 18   837  2015-12-20  D
# 19   703  2015-12-20  D
# 20   368  2015-12-20  D
# 21    82  2015-12-20  D
# 22   499  2015-12-20  D
# 23    68  2015-12-20  D
# 24   439  2015-12-20  D
# 25   602  2015-12-20  D
# 26   157  2015-12-20  D
# 27   324  2015-12-20  D
# 28   683  2015-12-20  D
# 29    43  2015-12-20  D
# ..   ...         ... ..
# 969  739  2015-12-20  D
# 970  327  2015-12-20  D
# 971  451  2015-12-20  D
# 972  429  2015-12-20  D
# 973  875  2015-12-20  D
# 974   33  2015-12-20  D
# ...

# %%
test0 = test0[test0[2]=='A']
test0
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
# 受領データの日付を取得
data = data.sort_values('order_date')
d2 = data['order_date'].unique()
#d2 = pd.DataFrame(d2)
d2
# Out:
# array(['2016-07-09', '2016-07-10', '2016-07-11', '2016-07-12',
#        '2016-07-13', '2016-07-14', '2016-07-15', '2016-07-16',
#        '2016-07-17', '2016-07-18', '2016-07-19', '2016-07-20',
#        '2016-07-21', '2016-07-22', '2016-07-23', '2016-07-24',
#        '2016-07-25', '2016-07-26', '2016-07-27', '2016-07-28',
#        '2016-07-29', '2016-07-30', '2016-07-31', '2016-08-01',
#        '2016-08-02', '2016-08-03', '2016-08-04', '2016-08-05',
#        '2016-08-06', '2016-08-07', '2016-08-08', '2016-08-09',
#        '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-13',
#        '2016-08-14', '2016-08-15', '2016-08-16', '2016-08-17',
#        '2016-08-18', '2016-08-19', '2016-08-20', '2016-08-21',
#        '2016-08-22', '2016-08-23', '2016-08-24', '2016-08-25',
#        '2016-08-26', '2016-08-27', '2016-08-28', '2016-08-29',
#        '2016-08-30', '2016-08-31', '2016-09-01', '2016-09-02',
#        '2016-09-03', '2016-09-04', '2016-09-05', '2016-09-06',
# ...

# %%
# 受領データの日付を検証1
for i in d2:
    d1 = "select * from rfmrank2('" + i +"');"
    cur.execute(d1)
    results = cur.fetchall()
    test1 = pd.DataFrame(results)
    test0 = pd.concat([test0, test1])

# %%
test0 = test0.rename(columns={0: 'user_id', 1: 'date', 2: 'RFM_Rank'})

# %%
test0
# Out:
#     user_id        date RFM_Rank
# 0       181  2016-07-09        D
# 1       962  2016-07-09        D
# 2       488  2016-07-09        D
# 3       131  2016-07-09        D
# 4       858  2016-07-09        D
# 5       954  2016-07-09        D
# 6       756  2016-07-09        D
# 7       423  2016-07-09        D
# 8       243  2016-07-09        D
# 9       135  2016-07-09        D
# 10       94  2016-07-09        D
# 11      294  2016-07-09        D
# 12      952  2016-07-09        D
# 13       25  2016-07-09        D
# 14      728  2016-07-09        D
# 15      937  2016-07-09        D
# 16      362  2016-07-09        D
# 17      204  2016-07-09        D
# 18      837  2016-07-09        D
# 19      703  2016-07-09        D
# 20      368  2016-07-09        D
# 21       82  2016-07-09        D
# 22      499  2016-07-09        D
# 23       68  2016-07-09        D
# 24      439  2016-07-09        D
# 25      602  2016-07-09        D
# 26      157  2016-07-09        D
# ...

# %%
d = '2015-12-20'
d3 = "select * from rfmrank_tran2('" + d + "','" + d +"');"
cur.execute(d3)
results = cur.fetchall()
test2 = pd.DataFrame(results)
test2
# Out:
#        0           1           2    3
# 0      0  2015-12-20  2015-12-20  D→D
# 1      1  2015-12-20  2015-12-20  D→D
# 2     10  2015-12-20  2015-12-20  D→D
# 3    100  2015-12-20  2015-12-20  D→D
# 4    101  2015-12-20  2015-12-20  D→D
# 5    102  2015-12-20  2015-12-20  D→D
# 6    103  2015-12-20  2015-12-20  D→D
# 7    104  2015-12-20  2015-12-20  D→D
# 8    105  2015-12-20  2015-12-20  D→D
# 9    106  2015-12-20  2015-12-20  D→D
# 10   107  2015-12-20  2015-12-20  D→D
# 11   108  2015-12-20  2015-12-20  D→D
# 12   109  2015-12-20  2015-12-20  D→D
# 13    11  2015-12-20  2015-12-20  D→D
# 14   110  2015-12-20  2015-12-20  D→D
# 15   111  2015-12-20  2015-12-20  D→D
# 16   112  2015-12-20  2015-12-20  D→D
# 17   113  2015-12-20  2015-12-20  D→D
# 18   114  2015-12-20  2015-12-20  D→D
# 19   115  2015-12-20  2015-12-20  D→D
# 20   116  2015-12-20  2015-12-20  D→D
# 21   117  2015-12-20  2015-12-20  D→D
# 22   118  2015-12-20  2015-12-20  D→D
# 23   119  2015-12-20  2015-12-20  D→D
# ...

# %%
test2 = test2[test2[2]=='A']
test2
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
# 受領データの日付を検証2
for i1 in d2:
    for i2 in d2:
        d1 = "select * from rfmrank_tran2('" + i1 + "','" + i2 +"');"
        cur.execute(d1)
        results = cur.fetchall()
        test3 = pd.DataFrame(results)
        test2 = pd.concat([test2, test3])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-da58d555d846> in <module>()
#       3     for i2 in d2:
#       4         d1 = "select * from rfmrank_tran2('" + i1 + "','" + i2 +"');"
# ----> 5         cur.execute(d1)
#       6         results = cur.fetchall()
#       7         test3 = pd.DataFrame(results)
#
# ~\Anaconda3\lib\encodings\utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:
